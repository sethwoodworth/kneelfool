# %%
import csv
import os
import pprint

# %%
gods = csv.reader?

# %%
with open('./KNEEL FOOL - Sheet1.csv', 'r') as sheet:
    sheet_iterator = csv.DictReader(sheet)
    gods = []
    for row in sheet_iterator:
        row.pop('')
        gods.append(row)

# %%
god = gods[0]

# %%
pprint.pprint( gods)
# Out:
# [{'Domains': 'Earth, Law, Nobility, Protection, Travel',
#   'Name': 'Bourgwad',
#   'Weapon': 'Dagger',
#   'alignment': 'LN',
#   'notes on imagery/story': "Dude's a real wad."},
#  {'Domains': 'Healing, Knowledge, Glory, Rune, Strength',
#   'Name': 'Nidalap',
#   'Weapon': 'Longsword',
#   'alignment': 'LN',
#   'notes on imagery/story': 'stupid knight type'},
#  {'Domains': 'Evil, Fire, Law, Magic, Trickery',
#   'Name': 'Abaddemon',
#   'Weapon': 'Whip',
#   'alignment': 'LE',
#   'notes on imagery/story': 'something s&m related obvs'},
#  {'Domains': 'Darkness, Death, Destruction, Scalykind, War',
#   'Name': 'Fafner',
#   'Weapon': 'Greatsword',
#   'alignment': 'LE',
#   'notes on imagery/story': 'BIG EVIL DRAGON'},
#  {'Domains': 'Animal, Community, Good, Law, Plant',
#   'Name': 'Assisi',
#   'Weapon': 'Light Crossbow',
#   'alignment': 'LG',
#   'notes on imagery/story': 'Sean Connery from that movie.'},
#  {'Domains': 'Glory, Healing, Protection, Repose, Sun',
# ...
